# %%
# Importing necessary libraries
# This script is designed to perform a specific task, and the libraries imported here are essential for its functionality.
import os
import sys
import logging
import argparse
import json
from datetime import datetime
from typing import List, Dict, Any

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
# If modules are not intalled, you can install them using pip
# !pip install numpy pandas matplotlib seaborn
# Importing data analysis and visualization libraries
# In requirements.txt, we have specified the versions of these libraries to ensure compatibility and reproducibility of our code.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       1 # If modules are not intalled, you can install them using pip
#       2 # !pip install numpy pandas matplotlib seaborn
#       3 # Importing data analysis and visualization libraries
#       4 # In requirements.txt, we have specified the versions of these libraries to ensure compatibility and reproducibility of our code.
# ----> 5 import numpy as np
#       6 import pandas as pd
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
from package.maths import addition
print(addition(5, 10))
# Out:
# 15
