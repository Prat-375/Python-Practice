# %% [markdown]
# # Module: Pandas Assignments
# ## Lesson: Pandas
# ### Assignment 1: DataFrame Creation and Indexing
#
# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
# 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.
#
# ### Assignment 2: DataFrame Operations
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.
#
# ### Assignment 3: Data Cleaning
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.
#
# ### Assignment 4: Data Aggregation
#
# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.
#
# ### Assignment 5: Merging DataFrames
#
# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.
#
# ### Assignment 6: Time Series Analysis
#
# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.
#
# ### Assignment 7: MultiIndex DataFrame
#
# 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.
# 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.
#
# ### Assignment 8: Pivot Tables
#
# 1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.
# 2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.
#
# ### Assignment 9: Applying Functions
#
# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
# 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.
#
# ### Assignment 10: Working with Text Data
#
# 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
# 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

# %%
### Assignment 1: DataFrame Creation and Indexing

# 1. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Set the index to be the first column.
# 2. Create a Pandas DataFrame with columns 'A', 'B', 'C' and index 'X', 'Y', 'Z'. Fill the DataFrame with random integers and access the element at row 'Y' and column 'B'.

import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5, 6],
    'B': [7, 8, 9, 10, 11, 12],
    'C': [13, 14, 15, 16, 17, 18],
    'D': [19, 20, 21, 22, 23, 24]
})
df.set_index('A', inplace=True)

print(df)

df2 = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}, index=['X', 'Y', 'Z'])

print(df2.loc['Y', 'B'])
# Out:
#     B   C   D
# A
# 1   7  13  19
# 2   8  14  20
# 3   9  15  21
# 4  10  16  22
# 5  11  17  23
# 6  12  18  24
# 5

# %%
### Assignment 2: DataFrame Operations

# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Add a new column that is the product of the first two columns.
# 2. Create a Pandas DataFrame with 3 columns and 4 rows filled with random integers. Compute the row-wise and column-wise sum.

import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [6, 7, 8, 9, 10],
    'C': [11, 12, 13, 14, 15]
})

df['D'] = df['A'] * df['B']

print(df)

df2 = pd.DataFrame({
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8],
    'C': [9, 10, 11, 12]
})

row_sum = df2.sum(axis=1)
col_sum = df2.sum(axis=0)
print("Row-wise sum:\n", row_sum)
print("Column-wise sum:\n", col_sum)
# Out:
#    A   B   C   D
# 0  1   6  11   6
# 1  2   7  12  14
# 2  3   8  13  24
# 3  4   9  14  36
# 4  5  10  15  50
# Row-wise sum:
#  0    15
# 1    18
# 2    21
# 3    24
# dtype: int64
# Column-wise sum:
#  A    10
# B    26
# C    42
# dtype: int64

# %%
### Assignment 3: Data Cleaning

# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Introduce some NaN values. Fill the NaN values with the mean of the respective columns.
# 2. Create a Pandas DataFrame with 4 columns and 6 rows filled with random integers. Introduce some NaN values. Drop the rows with any NaN values.

import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, None, 4, 5],
    'B': [6, None, 8, 9, 10],
    'C': [11, 12, 13, None, 15]
})

df.fillna(df.mean(), inplace=True)
print(df)

df2 = pd.DataFrame({
    'A': [1, 2, None, 4, 5, 6],
    'B': [7, 8, 9, None, 11, 12],
    'C': [13, 14, 15, 16, 17, None],
    'D': [19, 20, 21, 22, None, 24]
})

df2.dropna(inplace=True)
print(df2)
# Out:
#      A      B      C
# 0  1.0   6.00  11.00
# 1  2.0   8.25  12.00
# 2  3.0   8.00  13.00
# 3  4.0   9.00  12.75
# 4  5.0  10.00  15.00
#      A    B     C     D
# 0  1.0  7.0  13.0  19.0
# 1  2.0  8.0  14.0  20.0

# %%
### Assignment 4: Data Aggregation

# 1. Create a Pandas DataFrame with 2 columns: 'Category' and 'Value'. Fill the 'Category' column with random categories ('A', 'B', 'C') and the 'Value' column with random integers. Group the DataFrame by 'Category' and compute the sum and mean of 'Value' for each category.
# 2. Create a Pandas DataFrame with 3 columns: 'Product', 'Category', and 'Sales'. Fill the DataFrame with random data. Group the DataFrame by 'Category' and compute the total sales for each category.

import pandas as pd

df = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Value': [10, 20, 30, 40, 50, 60]
})

grouped = df.groupby('Category')['Value'].agg(['sum', 'mean'])
print(grouped)

df2 = pd.DataFrame({
    'Product': ['P1', 'P2', 'P3', 'P4', 'P5', 'P6'],
    'Category': ['A', 'B', 'C', 'A', 'B', 'C'],
    'Sales': [100, 200, 300, 400, 500, 600]
})

total_sales = df2.groupby('Category')['Sales'].sum()
print(total_sales)
# Out:
#           sum  mean
# Category
# A          50  25.0
# B          70  35.0
# C          90  45.0
# Category
# A    500
# B    700
# C    900
# Name: Sales, dtype: int64

# %%
### Assignment 5: Merging DataFrames

# 1. Create two Pandas DataFrames with a common column. Merge the DataFrames using the common column.
# 2. Create two Pandas DataFrames with different columns. Concatenate the DataFrames along the rows and along the columns.

import pandas as pd

df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie']
})

df2 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Age': [25, 30, 35]
})

merged_df = pd.merge(df1, df2, on='ID')
print(merged_df)

df3 = pd.DataFrame({
    'Product': ['P1', 'P2', 'P3'],
    'Price': [100, 200, 300]
})

df4 = pd.DataFrame({
    'Category': ['A', 'B', 'C'],
    'Stock': [10, 20, 30]
})

concatenated_rows = pd.concat([df3, df4], ignore_index=True) # Concatenate along rows and reset index
print(concatenated_rows)

concatenated_cols = pd.concat([df3, df4], axis=1) # Concatenate along columns 
print(concatenated_cols)
# Out:
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   3  Charlie   35
#   Product  Price Category  Stock
# 0      P1  100.0      NaN    NaN
# 1      P2  200.0      NaN    NaN
# 2      P3  300.0      NaN    NaN
# 3     NaN    NaN        A   10.0
# 4     NaN    NaN        B   20.0
# 5     NaN    NaN        C   30.0
#   Product  Price Category  Stock
# 0      P1    100        A     10
# 1      P2    200        B     20
# 2      P3    300        C     30

# %%
### Assignment 6: Time Series Analysis

# 1. Create a Pandas DataFrame with a datetime index and one column filled with random integers. Resample the DataFrame to compute the monthly mean of the values.
# 2. Create a Pandas DataFrame with a datetime index ranging from '2021-01-01' to '2021-12-31' and one column filled with random integers. Compute the rolling mean with a window of 7 days.

import pandas as pd

date_range = pd.date_range(start='2021-01-01', end='2021-12-31', freq='D')
df = pd.DataFrame({
    'Value': [i for i in range(len(date_range))]
}, index=date_range)

monthly_mean = df.resample('ME').mean()
print(monthly_mean)

rolling_mean = df.rolling(window=7).mean()
print(rolling_mean)
# Out:
#             Value
# 2021-01-31   15.0
# 2021-02-28   44.5
# 2021-03-31   74.0
# 2021-04-30  104.5
# 2021-05-31  135.0
# 2021-06-30  165.5
# 2021-07-31  196.0
# 2021-08-31  227.0
# 2021-09-30  257.5
# 2021-10-31  288.0
# 2021-11-30  318.5
# 2021-12-31  349.0
#             Value
# 2021-01-01    NaN
# 2021-01-02    NaN
# 2021-01-03    NaN
# 2021-01-04    NaN
# 2021-01-05    NaN
# ...           ...
# 2021-12-27  357.0
# 2021-12-28  358.0
# 2021-12-29  359.0
# 2021-12-30  360.0
# 2021-12-31  361.0
#
# [365 rows x 1 columns]

# %%
### Assignment 7: MultiIndex DataFrame

# 1. Create a Pandas DataFrame with a MultiIndex (hierarchical index). Perform some basic indexing and slicing operations on the MultiIndex DataFrame.
# 2. Create a Pandas DataFrame with MultiIndex consisting of 'Category' and 'SubCategory'. Fill the DataFrame with random data and compute the sum of values for each 'Category' and 'SubCategory'.

import pandas as pd

index = pd.MultiIndex.from_tuples([('A', 'X'), ('A', 'Y'), ('B', 'X'), ('B', 'Y')], names=['Category', 'SubCategory'])
df = pd.DataFrame({'Value': [1, 2, 3, 4]
}, index=index)

print(df)

# Basic indexing and slicing
print(df.loc['A']) # Access all rows for category 'A'
print(df.loc[('A', 'X')]) # Access the value for category 'A and subcategory 'X'

df2 = pd.DataFrame({
    'Value': [10, 20, 30, 40]
}, index=pd.MultiIndex.from_tuples([('A', 'X'), ('A', 'Y'), ('B', 'X'), ('B', 'Y')], names=['Category', 'SubCategory']))

grouped_sum = df2.groupby(['Category']).sum()

print(grouped_sum)
# Out:
#                       Value
# Category SubCategory
# A        X                1
#          Y                2
# B        X                3
#          Y                4
#              Value
# SubCategory
# X                1
# Y                2
# Value    1
# Name: (A, X), dtype: int64
#           Value
# Category
# A            30
# B            70

# %%
### Assignment 8: Pivot Tables

# 1. Create a Pandas DataFrame with columns 'Date', 'Category', and 'Value'. Create a pivot table to compute the sum of 'Value' for each 'Category' by 'Date'.
# 2. Create a Pandas DataFrame with columns 'Year', 'Quarter', and 'Revenue'. Create a pivot table to compute the mean 'Revenue' for each 'Quarter' by 'Year'.

import pandas as pd

df = pd.DataFrame({
    'Date': ['2021-01-01', '2021-01-01', '2021-01-02', '2021-01-02', '2021-01-03', '2021-01-03'],
    'Category': ['A', 'B', 'A', 'B', 'A', 'B'],
    'Value': [10, 20, 30, 40, 50, 60]
})

pivot_table = df.pivot_table(values='Value', index='Date', columns='Category', aggfunc='sum')
print(pivot_table)

df2 = pd.DataFrame({
    'Year': [2020, 2020, 2021, 2021],
    'Quarter': ['Q1', 'Q2', 'Q1', 'Q2'],
    'Revenue': [1000, 2000, 1500, 2500]
})

pivot_table2 = df2.pivot_table(values='Revenue', index='Year', columns='Quarter', aggfunc='mean')
print(pivot_table2)
# Out:
# Category     A   B
# Date
# 2021-01-01  10  20
# 2021-01-02  30  40
# 2021-01-03  50  60
# Quarter      Q1      Q2
# Year
# 2020     1000.0  2000.0
# 2021     1500.0  2500.0

# %%
### Assignment 9: Applying Functions

# 1. Create a Pandas DataFrame with 3 columns and 5 rows filled with random integers. Apply a function that doubles the values of the DataFrame.
# 2. Create a Pandas DataFrame with 3 columns and 6 rows filled with random integers. Apply a lambda function to create a new column that is the sum of the existing columns.

import pandas as pd
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [6, 7, 8, 9, 10],
    'C': [11, 12, 13, 14, 15]
})
df_doubled = df.apply(lambda x: x * 2)
print(df_doubled)

df2 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5, 6],
    'B': [7, 8, 9, 10, 11, 12],
    'C': [13, 14, 15, 16, 17, 18]
})

df2['Sum'] = df2.apply(lambda row: row['A'] + row['B'] + row['C'], axis=1)

print(df2)
# Out:
#     A   B   C
# 0   2  12  22
# 1   4  14  24
# 2   6  16  26
# 3   8  18  28
# 4  10  20  30
#    A   B   C  Sum
# 0  1   7  13   21
# 1  2   8  14   24
# 2  3   9  15   27
# 3  4  10  16   30
# 4  5  11  17   33
# 5  6  12  18   36

# %%
### Assignment 10: Working with Text Data

# 1. Create a Pandas Series with 5 random text strings. Convert all the strings to uppercase.
# 2. Create a Pandas Series with 5 random text strings. Extract the first three characters of each string.

import pandas as pd

text_series = pd.Series(['hello', 'world', 'pandas', 'data', 'analysis'])
uppercase_series = text_series.str.upper()
print(uppercase_series)

text_series = pd.Series(['hello', 'world', 'pandas', 'data', 'analysis'])
first_three_chars = text_series.str[:3]
print(first_three_chars)
# Out:
# 0       HELLO
# 1       WORLD
# 2      PANDAS
# 3        DATA
# 4    ANALYSIS
# dtype: str
# 0    hel
# 1    wor
# 2    pan
# 3    dat
# 4    ana
# dtype: str
