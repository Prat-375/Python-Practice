# %%
## What is If statement
# The if statement is a fundamental control structure in programming that allows you to execute a block of code only if a specified condition is true. It is used to make decisions in your code and control the flow of execution based on certain conditions. The basic syntax of an if statement in Python is as follows:
# if condition:
#     # code to execute if the condition is true
# You can also include an else clause to specify code that should be executed if the condition is false:
# else:
#     # code to execute if the condition is false
# Additionally, you can use elif (short for "else if") to check multiple conditions:
# elif another_condition:
#     # code to execute if another_condition is true

age = 20

if age > 18:
    print("You are an adult.")
elif age == 18:
    print("Congratulations on reaching adulthood!")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
## Nested Conditional Statements
# You can also nest if statements within each other to create more complex decision-making structures. This allows you to check multiple conditions in a hierarchical manner.

num = int(input("Enter a number: "))
if num > 0:
    print("The number is positive.")
    if num % 2 == 0:
        print("The number is even.")
    else:
        print("The number is odd.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# The number is negative.

# %%
## Some Examples
# Example 1: Print triangle type based on the lengths of its sides
side1 = float(input("Enter the length of the first side: "))
side2 = float(input("Enter the length of the second side: "))
side3 = float(input("Enter the length of the third side: "))

if side1 == side2 == side3:
    print("The triangle is equilateral.")
elif side1 == side2 or side2 == side3 or side1 == side3:
    print("The triangle is isosceles.")
else:
    print("The triangle is scalene.")
# Out:
# The triangle is isosceles.

# %%
# Example 2: Determine if a sentence is a question, statement, or exclamation
sentence = input("Enter a sentence: ")
if sentence.endswith("?"):
    print("The sentence is a question.")
elif sentence.endswith("!"):
    print("The sentence is an exclamation.")
else:
    print("The sentence is a statement.")
# Out:
# The sentence is a question.

# %%
# Example 3: Check if a circle covers a square
import math
radius = float(input("Enter the radius of the circle: "))
side_length = float(input("Enter the side length of the square: "))
if radius >= (side_length / math.sqrt(2)):
    print("The circle can cover the square.")
else:
    print("The circle cannot cover the square.")
# Out:
# The circle can cover the square.

# %%
## Simple Calculator:
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

operation = input("Enter the operation (+, -, *, /): ")
if operation == "+":
    result = num1 + num2
    print(f"The result of {num1} + {num2} is: {result}")
elif operation == "-":
    result = num1 - num2
    print(f"The result of {num1} - {num2} is: {result}")
elif operation == "*":
    result = num1 * num2
    print(f"The result of {num1} * {num2} is: {result}")
elif operation == "/":
    if num2 != 0:
        result = num1 / num2
        print(f"The result of {num1} / {num2} is: {result}")
    else:
        print("Error: Division by zero is not allowed.")
else:
    print("Invalid operation. Please enter one of +, -, *, or /.")
# Out:
# The result of 5.0 + 2.0 is: 7.0

# %%
## Determine the Ticket price based on age
age = int(input("Enter your age: "))
if age < 0:
    print("Invalid age. Age cannot be negative.")
elif age < 12:
    print("You are eligible for a child ticket.")
elif age < 18:
    print("You are eligible for a youth ticket.")
elif age < 65:
    print("You are eligible for an adult ticket.")
else:
    print("You are eligible for a senior ticket.")
# Out:
# You are eligible for an adult ticket.
